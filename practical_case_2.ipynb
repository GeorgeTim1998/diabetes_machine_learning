# %%
import pandas as pd
from matplotlib import pyplot
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('aridata/diabetes.csv') # загружаем файл
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df.Outcome
x = df.drop(['Outcome'], axis=1)

print('------------------- Наш X ------------------')
print(x)

print('------------------- Наш Y ------------------')
print(y)
# Out:
# ------------------- Наш X ------------------
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
# разделяем данные на обучающие и тестовые
X_train, X_test, Y_train, Y_test = train_test_split(x, y, random_state=0)  # test_size=0.3, stratify=y

# %%
# создаем классификатор
clf = DecisionTreeClassifier(criterion="entropy", max_depth=2, random_state=0)

# %%
# обучаем дерево решений
clf.fit(X_train, Y_train)
print(tree.plot_tree(clf))
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= 123.5\nentropy = 0.941\nsamples = 576\nvalue = [370, 206]'), Text(0.25, 0.5, 'x[5] <= 26.45\nentropy = 0.685\nsamples = 329\nvalue = [269, 60]'), Text(0.125, 0.16666666666666666, 'entropy = 0.087\nsamples = 92\nvalue = [91, 1]'), Text(0.375, 0.16666666666666666, 'entropy = 0.81\nsamples = 237\nvalue = [178, 59]'), Text(0.75, 0.5, 'x[5] <= 30.05\nentropy = 0.976\nsamples = 247\nvalue = [101, 146]'), Text(0.625, 0.16666666666666666, 'entropy = 0.881\nsamples = 70\nvalue = [49, 21]'), Text(0.875, 0.16666666666666666, 'entropy = 0.874\nsamples = 177\nvalue = [52, 125]')]

# %%
# ------------------- Визуализация дерева------------------')

fig, axes = pyplot.subplots(nrows=1, ncols=1, figsize=(4, 4), dpi=300)
tree.plot_tree(clf,
               feature_names=None,
               class_names=None,
               filled=True)
pyplot.show()

# %% [markdown]
# # Вывод
#
# Был освоен анализ тестовых данных при помощи обученного дерева решений.
# Полученное дерево было визуализировано
